# %% [markdown]
# # Assignment # 21 Solutions

# %% [markdown]
# ### 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 17-05-2023

# %% [markdown]
# ### 2. Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 17-05-2023

# %% [markdown]
# ### 3. Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2023-05-17 00:00:00

# %% [markdown]
# ### 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# 01.Assignment_01.ipynb
# 01.Programming Assignment_01.ipynb
# 02.Assignment_02.ipynb
# 02.Programming Assignment_02.ipynb
# 03.Assignment_03.ipynb
# 03.Programming Assignment_03.ipynb
# 04.Assignment_04.ipynb
# 04.Programming Assignment_04.ipynb
# 05.Assignment_05.ipynb
# 05.Programming Assignment_05.ipynb
# 06.Assignment_06.ipynb
# 06.Programming Assignment_06.ipynb
# 07.Assignment_07.ipynb
# 07.Programming Assignment_07.ipynb
# 08.Assignment_08.ipynb
# 08.Programming Assignment_08.ipynb
# 09.Assignment_09.ipynb
# 09.Programming Assignment_09.ipynb
# 0_Untitled spreadsheet.pdf
# 0_Untitled spreadsheet.xlsx
# 10.Assignment_10.ipynb
# 10.Programming Assignment_10.ipynb
# 10th Certificate.jpg
# 10th Certificate.pdf
# 11.Assignment_11.ipynb
# 11.Programming Assignment_11.ipynb
# 12.Assignment_12.ipynb
# 12.Programming Assignment_12.ipynb
# 13.Assignment_13.ipynb
# 13.Programming Assignment_13.ipynb
# 14.Assignment_14.ipynb
# 14.Programming Assignment_14.ipynb
# 15.Assignment_15.ipynb
# 15.Programming Assignment_15.ipynb
# 16.Assignment_16.ipynb
# 16.Programming Assignment_16.ipynb
# 17.Assignment_17.ipynb
# 17.Programming Assignment_17.ipynb
# 18.Assignment_18.ipynb
# 18.Programming Assignment_18.ipynb
# 19.Assignment_19.ipynb
# 19.Programming Assignment_19.ipynb
# 20.Assignment_20.ipynb
# 20.Programming Assignment_20.ipynb
# 21.Assignment_21.ipynb
# 21.Programming Assignment_21.ipynb
# 22.Assignment_22.ipynb
# 22.Programming Assignment_22.ipynb
# 23.Assignment_23.ipynb
# 23.Programming Assignment_23.ipynb
# 24.Assignment_24.ipynb
# 24.Programming Assignment_24.ipynb
# 25.Assignment_25.ipynb
# 25.Programming Assignment_25.ipynb
# 3rdJulyResourceLink.docx
# 5th June, Assignment.ipynb
# 6931938-ef43d46682f2792eeeb30901cc830f37.docx
# Anaconda3-2021.11-Windows-x86_64.exe
# application_log.txt
# B.Tech Certificate.jpg
# B.Tech Certificate.pdf
# bank.zip
# books.csv
# books.db
# Caste  Certificate .pdf
# ChromeSetup (1).exe
# ChromeSetup.exe
# COVID-19 Cases.csv
# Credit Card Default Prediction.pdf
# dbt setup (1).docx
# dbt setup.docx
# Dec 04, 2021 (1).txt
# Dec 04, 2021.txt
# desktop.ini
# DLsawan.pdf
# DOC-20220714-WA0005.docx
# Fivetran Task.docx
# Fivetran Task.pdf
# Full Stack Data Science.pdf
# Git-2.37.2.2-64-bit.exe
# Government Job Notification Application.pdf
# Govind Resume.pdf
# images (1).jpeg
# Jana Gana Mana (2022) TRUE WEB-DL - 1080p - AVC - DD+5.1 [Tam + Tel + Mal + Kan].srt
# machine_practices_problems-main(FSDS_Bootcamp Questions 9th Oct) (1).zip
# machine_practices_problems-main(FSDS_Bootcamp Questions 9th Oct).zip
# MailAttachment_003371655.pdf
# mysql-installer-community-8.0.30.0.msi
# Nanu Vadhilelina Thanatho Lyrical Song __ Backbenchers Web Series __ Dorasai Teja __ Infinitum Media.mp3
# NC .pdf
# OPPS_day_2.rar
# pic.jpg
# pic2.jpg
# Postman-win64-Setup.exe
# Priti_.docx
# Proof of Category (1).pdf
# Proof of Category (10).pdf
# Proof of Category (11).pdf
# Proof of Category (12).pdf
# Proof of Category (2).pdf
# Proof of Category (3).pdf
# Proof of Category (4).pdf
# Proof of Category (5).pdf
# Proof of Category (6).pdf
# Proof of Category (7).pdf
# Proof of Category (8).pdf
# Proof of Category (9).pdf
# Proof of Category.pdf
# Proof of Non-creamy Layer (1).pdf
# Proof of Non-creamy Layer (2).pdf
# Proof of Non-creamy Layer.pdf
# pycharm-community-2022.1.exe
# Python Basic-Assignment 07.ipynb
# Python Basic-Assignment 08.ipynb
# Python Basic-Assignment 09.ipynb
# Python Basic-Assignment 10.ipynb
# Python Basics-Assignment 20 (1).ipynb
# Python Basics-Assignment 20.ipynb
# Python Basics-Assignment 21.ipynb
# python-3.10.4-amd64.exe
# python-3.8.9-amd64.exe
# Ravanasura-(2023)-Telugu-Original-HDRip-720p-HQ.mp4
# raw_customers.csv
# raw_orders.csv
# raw_payments.csv
# Receipt_Details_1793488 (1).html
# Receipt_Details_1793488 (2).html
# Receipt_Details_1793488.html
# Receipt_Details_2876612.html
# Restaurant Rating Prediction.pdf
# Resume _ iNeuron.ai.docx
# Sagar PPT.pptx
# sawan.txt
# Screenshot_20220524-215842.jpg
# SPS_9.4.7.25_1033.cab
# SQL2019-SSEI-Dev.exe
# SSMS-Setup-ENU.exe
# Table and column naming rule set.xlsx
# test.txt
# today.txt
# tsetup-x64.3.7.3.exe
# university_records.csv
# Untitled.ipynb
# Video resume sawan.mp4
# VID_60850911_153417_408_111225.mp4
# vlc-3.0.7.1-win64.exe
# War-2019.mp4
# Web capture_14-9-2022_135951_miro.medium.com.jpeg
# Webex.exe
# zoo.ipynb
# zoo.py
# ZoomInstaller.exe
# Zoom_cm_fo42pnktZ9vvrZo4_mj3ybKz+KW1FwDwkoKUN8+3v0Ohr47Fm4Rv0i@iCsScM6o1xrXCDIF_k47dfb52d1f0d7cc1_.exe
# .gitignore
# .name
# Downloads.iml
# misc.xml
# modules.xml
# vcs.xml
# workspace.xml
# profiles_settings.xml
# 01.Assignment_01-checkpoint.ipynb
# 02.Assignment_02-checkpoint.ipynb
# 03.Assignment_03-checkpoint.ipynb
# 04.Assignment_04-checkpoint.ipynb
# 05.Assignment_05-checkpoint.ipynb
# 06.Assignment_06-checkpoint.ipynb
# 07.Assignment_07-checkpoint.ipynb
# 08.Assignment_08-checkpoint.ipynb
# 09.Assignment_09-checkpoint.ipynb
# 10.Assignment_10-checkpoint.ipynb
# 11.Assignment_11-checkpoint.ipynb
# 12.Assignment_12-checkpoint.ipynb
# 13.Assignment_13-checkpoint.ipynb
# 14.Assignment_14-checkpoint.ipynb
# 15.Assignment_15-checkpoint.ipynb
# 16.Assignment_16-checkpoint.ipynb
# 17.Assignment_17-checkpoint.ipynb
# 18.Assignment_18-checkpoint.ipynb
# 19.Assignment_19-checkpoint.ipynb
# 20.Assignment_20-checkpoint.ipynb
# 21.Assignment_21-checkpoint.ipynb
# Python Basic-Assignment 07-checkpoint.ipynb
# Python Basic-Assignment 08-checkpoint.ipynb
# Python Basic-Assignment 09-checkpoint.ipynb
# Python Basic-Assignment 10-checkpoint.ipynb
# Python Basics - Assignment 2-checkpoint.ipynb
# Python Basics-Assignment 03-checkpoint.ipynb
# Python Basics-Assignment 04-checkpoint.ipynb
# Python Basics-Assignment 05-checkpoint.ipynb
# Python Basics-Assignment 06-checkpoint.ipynb
# Python Basics-Assignment 11-checkpoint.ipynb
# Python Basics-Assignment 12-checkpoint.ipynb
# Python Basics-Assignment 13-checkpoint.ipynb
# Python Basics-Assignment 14-checkpoint.ipynb
# Python Basics-Assignment 15-checkpoint.ipynb
# Python Basics-Assignment 16-checkpoint.ipynb
# Python Basics-Assignment 17-checkpoint.ipynb
# Python Basics-Assignment 18-checkpoint.ipynb
# Python Basics-Assignment 19-checkpoint.ipynb
# Python Basics-Assignment 20-checkpoint.ipynb
# Python Basics-Assignment 21-checkpoint.ipynb
# python variable part 1 (1)-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# zoo-checkpoint.ipynb
# bank-full.csv
# bank-names.txt
# bank.csv
# Adhar Card- Sagar.pdf
# Driving licence-Sagar.pdf
# DrivinglicenceSagar.pdf
# e-Receipt For Online Driving License- Sagar.pdf
# LMV Learning license- Sagar.pdf
# LMV license Application - Sagar.pdf
# Self declaration LMV license- Sagar.pdf
# AWS.txt
# DB Instance database-1.txt
# Fivetran.txt
# Gdrive links.txt
# Github.txt
# Snowflake.txt
# Internship Certificate.pdf
# test1234.csv
# Assignment_1.docx
# Assignment_10.docx
# Assignment_11.docx
# Assignment_12.docx
# Assignment_13.docx
# Assignment_14.docx
# Assignment_15.docx
# Assignment_16.docx
# Assignment_17.docx
# Assignment_18.docx
# Assignment_19.docx
# Assignment_2.docx
# Assignment_20.docx
# Assignment_21.docx
# Assignment_22.docx
# Assignment_23.docx
# Assignment_24.docx
# Assignment_3.docx
# Assignment_4.docx
# Assignment_5.docx
# Assignment_6.docx
# Assignment_7.docx
# Assignment_8.docx
# Assignment_9.docx
# Assignment_1.docx
# Assignment_10.docx
# Assignment_11.docx
# Assignment_12.docx
# Assignment_13.docx
# Assignment_14.docx
# Assignment_15.docx
# Assignment_16.docx
# Assignment_17.docx
# Assignment_18.docx
# Assignment_19.docx
# Assignment_2.docx
# Assignment_20.docx
# Assignment_21.docx
# Assignment_22.docx
# Assignment_23.docx
# Assignment_24.docx
# Assignment_25.docx
# Assignment_3.docx
# Assignment_4.docx
# Assignment_5.docx
# Assignment_6.docx
# Assignment_7.docx
# Assignment_8.docx
# Assignment_9.docx
# Assignment_1.docx
# Assignment_10.docx
# Assignment_11.docx
# Assignment_12.docx
# Assignment_13.docx
# Assignment_14.docx
# Assignment_15.docx
# Assignment_16.docx
# Assignment_17.docx
# Assignment_18.docx
# Assignment_19.docx
# Assignment_2.docx
# Assignment_20.docx
# Assignment_21.docx
# Assignment_22.docx
# Assignment_23.docx
# Assignment_24.docx
# Assignment_25.docx
# Assignment_3.docx
# Assignment_4.docx
# Assignment_5.docx
# Assignment_6.docx
# Assignment_7.docx
# Assignment_8.docx
# Assignment_9.docx
# Programming_Assingment1.docx
# Programming_Assingment10.docx
# Programming_Assingment11.docx
# Programming_Assingment12.docx
# Programming_Assingment13.docx
# Programming_Assingment14.docx
# Programming_Assingment15.docx
# Programming_Assingment16.docx
# Programming_Assingment17.docx
# Programming_Assingment18.docx
# Programming_Assingment19.docx
# Programming_Assingment2.docx
# Programming_Assingment20.docx
# Programming_Assingment21.docx
# Programming_Assingment22.docx
# Programming_Assingment23.docx
# Programming_Assingment24.docx
# Programming_Assingment25.docx
# Programming_Assingment3.docx
# Programming_Assingment4.docx
# Programming_Assingment5.docx
# Programming_Assingment6.docx
# Programming_Assingment7.docx
# Programming_Assingment8.docx
# Programming_Assingment9.docx
# Python Basics-Assignment 01.ipynb
# Python Basics-Assignment 02.ipynb
# Python Basics-Assignment 03.ipynb
# Python Basics-Assignment 04.ipynb
# Python Basics-Assignment 05.ipynb
# Python Basics-Assignment 06.ipynb
# Python Basics-Assignment 07.ipynb
# Python Basics-Assignment 08.ipynb
# Python Basics-Assignment 09.ipynb
# Python Basics-Assignment 10.ipynb
# Python Basics-Assignment 11.ipynb
# Python Basics-Assignment 12.ipynb
# Python Basics-Assignment 13.ipynb
# Python Basics-Assignment 14.ipynb
# Python Basics-Assignment 15.ipynb
# Python Basics-Assignment 16.ipynb
# Python Basics-Assignment 17.ipynb
# Python Basics-Assignment 18.ipynb
# Python Basics-Assignment 19.ipynb
# 28May Assignment.ipynb
# assignment 21stMay.ipynb
# FSDS 2022 15th May Assignment, Sawan Basanwar.ipynb
# .gitignore
# Class HW.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# main.py
# test1.py
# .gitignore
# 11june practice.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# test1.py
# test2.py
# test3.py
# test4.py
# .gitignore
# .name
# misc.xml
# modules.xml
# OOPS 24thjuly.iml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# .gitignore
# pyvenv.cfg
# distutils-precedence.pth
# libcrypto-1_1-x64.dll
# libmysql.dll
# libssl-1_1-x64.dll
# protobuf-3.20.1-py3.10-nspkg.pth
# setuptools-60.2.0.virtualenv
# wheel-0.37.1.virtualenv
# _mysqlxpb.cp310-win_amd64.pyd
# _mysql_connector.cp310-win_amd64.pyd
# _virtualenv.pth
# _virtualenv.py
# any_pb2.py
# api_pb2.py
# descriptor.py
# descriptor_database.py
# descriptor_pb2.py
# descriptor_pool.py
# duration_pb2.py
# empty_pb2.py
# field_mask_pb2.py
# json_format.py
# message.py
# message_factory.py
# proto_builder.py
# reflection.py
# service.py
# service_reflection.py
# source_context_pb2.py
# struct_pb2.py
# symbol_database.py
# text_encoding.py
# text_format.py
# timestamp_pb2.py
# type_pb2.py
# wrappers_pb2.py
# __init__.py
# plugin_pb2.py
# __init__.py
# plugin_pb2.cpython-310.pyc
# __init__.cpython-310.pyc
# api_implementation.py
# builder.py
# containers.py
# decoder.py
# encoder.py
# enum_type_wrapper.py
# extension_dict.py
# message_listener.py
# message_set_extensions_pb2.py
# missing_enum_values_pb2.py
# more_extensions_dynamic_pb2.py
# more_extensions_pb2.py
# more_messages_pb2.py
# no_package_pb2.py
# python_message.py
# type_checkers.py
# well_known_types.py
# wire_format.py
# _api_implementation.cp310-win_amd64.pyd
# _parameterized.py
# __init__.py
# api_implementation.cpython-310.pyc
# builder.cpython-310.pyc
# containers.cpython-310.pyc
# decoder.cpython-310.pyc
# encoder.cpython-310.pyc
# enum_type_wrapper.cpython-310.pyc
# extension_dict.cpython-310.pyc
# message_listener.cpython-310.pyc
# message_set_extensions_pb2.cpython-310.pyc
# missing_enum_values_pb2.cpython-310.pyc
# more_extensions_dynamic_pb2.cpython-310.pyc
# more_extensions_pb2.cpython-310.pyc
# more_messages_pb2.cpython-310.pyc
# no_package_pb2.cpython-310.pyc
# python_message.cpython-310.pyc
# type_checkers.cpython-310.pyc
# well_known_types.cpython-310.pyc
# wire_format.cpython-310.pyc
# _parameterized.cpython-310.pyc
# __init__.cpython-310.pyc
# cpp_message.py
# python_pb2.py
# _message.cp310-win_amd64.pyd
# __init__.py
# cpp_message.cpython-310.pyc
# python_pb2.cpython-310.pyc
# __init__.cpython-310.pyc
# json_format_pb2.py
# json_format_proto3_pb2.py
# __init__.py
# json_format_pb2.cpython-310.pyc
# json_format_proto3_pb2.cpython-310.pyc
# __init__.cpython-310.pyc
# any_pb2.cpython-310.pyc
# api_pb2.cpython-310.pyc
# descriptor.cpython-310.pyc
# descriptor_database.cpython-310.pyc
# descriptor_pb2.cpython-310.pyc
# descriptor_pool.cpython-310.pyc
# duration_pb2.cpython-310.pyc
# empty_pb2.cpython-310.pyc
# field_mask_pb2.cpython-310.pyc
# json_format.cpython-310.pyc
# message.cpython-310.pyc
# message_factory.cpython-310.pyc
# proto_builder.cpython-310.pyc
# reflection.cpython-310.pyc
# service.cpython-310.pyc
# service_reflection.cpython-310.pyc
# source_context_pb2.cpython-310.pyc
# struct_pb2.cpython-310.pyc
# symbol_database.cpython-310.pyc
# text_encoding.cpython-310.pyc
# text_format.cpython-310.pyc
# timestamp_pb2.cpython-310.pyc
# type_pb2.cpython-310.pyc
# wrappers_pb2.cpython-310.pyc
# __init__.cpython-310.pyc
# __init__.py
# abstracts.py
# authentication.py
# charsets.py
# connection.py
# connection_cext.py
# constants.py
# conversion.py
# cursor.py
# cursor_cext.py
# custom_types.py
# dbapi.py
# errorcode.py
# errors.py
# network.py
# optionfiles.py
# pooling.py
# protocol.py
# utils.py
# version.py
# __init__.py
# base.py
# client.py
# compiler.py
# creation.py
# features.py
# introspection.py
# operations.py
# schema.py
# validation.py
# __init__.py
# base.cpython-310.pyc
# client.cpython-310.pyc
# compiler.cpython-310.pyc
# creation.cpython-310.pyc
# features.cpython-310.pyc
# introspection.cpython-310.pyc
# operations.cpython-310.pyc
# schema.cpython-310.pyc
# validation.cpython-310.pyc
# __init__.cpython-310.pyc
# __init__.py
# client_error.py
# __init__.py
# client_error.cpython-310.pyc
# __init__.cpython-310.pyc
# __init__.cpython-310.pyc
# authentication_kerberos_client.py
# authentication_ldap_sasl_client.py
# authentication_oci_client.py
# caching_sha2_password.py
# mysql_clear_password.py
# mysql_native_password.py
# sha256_password.py
# __init__.py
# authentication_kerberos_client.cpython-310.pyc
# authentication_ldap_sasl_client.cpython-310.pyc
# authentication_oci_client.cpython-310.pyc
# caching_sha2_password.cpython-310.pyc
# mysql_clear_password.cpython-310.pyc
# mysql_native_password.cpython-310.pyc
# sha256_password.cpython-310.pyc
# __init__.cpython-310.pyc
# abstracts.cpython-310.pyc
# authentication.cpython-310.pyc
# charsets.cpython-310.pyc
# connection.cpython-310.pyc
# connection_cext.cpython-310.pyc
# constants.cpython-310.pyc
# conversion.cpython-310.pyc
# cursor.cpython-310.pyc
# cursor_cext.cpython-310.pyc
# custom_types.cpython-310.pyc
# dbapi.cpython-310.pyc
# errorcode.cpython-310.pyc
# errors.cpython-310.pyc
# network.cpython-310.pyc
# optionfiles.cpython-310.pyc
# pooling.cpython-310.pyc
# protocol.cpython-310.pyc
# utils.cpython-310.pyc
# version.cpython-310.pyc
# __init__.cpython-310.pyc
# libcrypto-1_1-x64.dll
# libsasl.dll
# libssl-1_1-x64.dll
# saslSCRAM.dll
# authentication_fido_client.dll
# authentication_kerberos_client.dll
# authentication_ldap_sasl_client.dll
# authentication_oci_client.dll
# __init__.cpython-310.pyc
# authentication.py
# charsets.py
# connection.py
# constants.py
# crud.py
# dbdoc.py
# errorcode.py
# errors.py
# expr.py
# helpers.py
# protocol.py
# result.py
# statement.py
# __init__.py
# __init__.py
# client_error.py
# __init__.py
# client_error.cpython-310.pyc
# __init__.cpython-310.pyc
# __init__.cpython-310.pyc
# mysqlx_connection_pb2.py
# mysqlx_crud_pb2.py
# mysqlx_cursor_pb2.py
# mysqlx_datatypes_pb2.py
# mysqlx_expect_pb2.py
# mysqlx_expr_pb2.py
# mysqlx_notice_pb2.py
# mysqlx_pb2.py
# mysqlx_prepare_pb2.py
# mysqlx_resultset_pb2.py
# mysqlx_session_pb2.py
# mysqlx_sql_pb2.py
# __init__.py
# mysqlx_connection_pb2.cpython-310.pyc
# mysqlx_crud_pb2.cpython-310.pyc
# mysqlx_cursor_pb2.cpython-310.pyc
# mysqlx_datatypes_pb2.cpython-310.pyc
# mysqlx_expect_pb2.cpython-310.pyc
# mysqlx_expr_pb2.cpython-310.pyc
# mysqlx_notice_pb2.cpython-310.pyc
# mysqlx_pb2.cpython-310.pyc
# mysqlx_prepare_pb2.cpython-310.pyc
# mysqlx_resultset_pb2.cpython-310.pyc
# mysqlx_session_pb2.cpython-310.pyc
# mysqlx_sql_pb2.cpython-310.pyc
# __init__.cpython-310.pyc
# authentication.cpython-310.pyc
# charsets.cpython-310.pyc
# connection.cpython-310.pyc
# constants.cpython-310.pyc
# crud.cpython-310.pyc
# dbdoc.cpython-310.pyc
# errorcode.cpython-310.pyc
# errors.cpython-310.pyc
# expr.cpython-310.pyc
# helpers.cpython-310.pyc
# protocol.cpython-310.pyc
# result.cpython-310.pyc
# statement.cpython-310.pyc
# __init__.cpython-310.pyc
# INSTALLER
# LICENSE.txt
# METADATA
# RECORD
# REQUESTED
# top_level.txt
# WHEEL
# py.typed
# __init__.py
# __main__.py
# __pip-runner__.py
# build_env.py
# cache.py
# configuration.py
# exceptions.py
# main.py
# pyproject.py
# self_outdated_check.py
# wheel_builder.py
# __init__.py
# autocompletion.py
# base_command.py
# cmdoptions.py
# command_context.py
# main.py
# main_parser.py
# parser.py
# progress_bars.py
# req_command.py
# spinners.py
# status_codes.py
# __init__.py
# autocompletion.cpython-310.pyc
# base_command.cpython-310.pyc
# cmdoptions.cpython-310.pyc
# command_context.cpython-310.pyc
# main.cpython-310.pyc
# main_parser.cpython-310.pyc
# parser.cpython-310.pyc
# progress_bars.cpython-310.pyc
# req_command.cpython-310.pyc
# spinners.cpython-310.pyc
# status_codes.cpython-310.pyc
# __init__.cpython-310.pyc
# cache.py
# check.py
# completion.py
# configuration.py
# debug.py
# download.py
# freeze.py
# hash.py
# help.py
# index.py
# inspect.py
# install.py
# list.py
# search.py
# show.py
# uninstall.py
# wheel.py
# __init__.py
# cache.cpython-310.pyc
# check.cpython-310.pyc
# completion.cpython-310.pyc
# configuration.cpython-310.pyc
# debug.cpython-310.pyc
# download.cpython-310.pyc
# freeze.cpython-310.pyc
# hash.cpython-310.pyc
# help.cpython-310.pyc
# index.cpython-310.pyc
# inspect.cpython-310.pyc
# install.cpython-310.pyc
# list.cpython-310.pyc
# search.cpython-310.pyc
# show.cpython-310.pyc
# uninstall.cpython-310.pyc
# wheel.cpython-310.pyc
# __init__.cpython-310.pyc
# base.py
# installed.py
# sdist.py
# wheel.py
# __init__.py
# base.cpython-310.pyc
# installed.cpython-310.pyc
# sdist.cpython-310.pyc
# wheel.cpython-310.pyc
# __init__.cpython-310.pyc
# collector.py
# package_finder.py
# sources.py
# __init__.py
# collector.cpython-310.pyc
# package_finder.cpython-310.pyc
# sources.cpython-310.pyc
# __init__.cpython-310.pyc
# base.py
# _distutils.py
# _sysconfig.py
# __init__.py
# base.cpython-310.pyc
# _distutils.cpython-310.pyc
# _sysconfig.cpython-310.pyc
# __init__.cpython-310.pyc
# base.py
# pkg_resources.py
# _json.py
# __init__.py
# _compat.py
# _dists.py
# _envs.py
# __init__.py
# _compat.cpython-310.pyc
# _dists.cpython-310.pyc
# _envs.cpython-310.pyc
# __init__.cpython-310.pyc
# base.cpython-310.pyc
# pkg_resources.cpython-310.pyc
# _json.cpython-310.pyc
# __init__.cpython-310.pyc
# candidate.py
# direct_url.py
# format_control.py
# index.py
# installation_report.py
# link.py
# scheme.py
# search_scope.py
# selection_prefs.py
# target_python.py
# wheel.py
# __init__.py
# candidate.cpython-310.pyc
# direct_url.cpython-310.pyc
# format_control.cpython-310.pyc
# index.cpython-310.pyc
# installation_report.cpython-310.pyc
# link.cpython-310.pyc
# scheme.cpython-310.pyc
# search_scope.cpython-310.pyc
# selection_prefs.cpython-310.pyc
# target_python.cpython-310.pyc
# wheel.cpython-310.pyc
# __init__.cpython-310.pyc
# auth.py
# cache.py
# download.py
# lazy_wheel.py
# session.py
# utils.py
# xmlrpc.py
# __init__.py
# auth.cpython-310.pyc
# cache.cpython-310.pyc
# download.cpython-310.pyc
# lazy_wheel.cpython-310.pyc
# session.cpython-310.pyc
# utils.cpython-310.pyc
# xmlrpc.cpython-310.pyc
# __init__.cpython-310.pyc
# check.py
# freeze.py
# prepare.py
# __init__.py
# build_tracker.py
# metadata.py
# metadata_editable.py
# metadata_legacy.py
# wheel.py
# wheel_editable.py
# wheel_legacy.py
# __init__.py
# build_tracker.cpython-310.pyc
# metadata.cpython-310.pyc
# metadata_editable.cpython-310.pyc
# metadata_legacy.cpython-310.pyc
# wheel.cpython-310.pyc
# wheel_editable.cpython-310.pyc
# wheel_legacy.cpython-310.pyc
# __init__.cpython-310.pyc
# editable_legacy.py
# legacy.py
# wheel.py
# __init__.py
# editable_legacy.cpython-310.pyc
# legacy.cpython-310.pyc
# wheel.cpython-310.pyc
# __init__.cpython-310.pyc
# check.cpython-310.pyc
# freeze.cpython-310.pyc
# prepare.cpython-310.pyc
# __init__.cpython-310.pyc
# constructors.py
# req_file.py
# req_install.py
# req_set.py
# req_uninstall.py
# __init__.py
# constructors.cpython-310.pyc
# req_file.cpython-310.pyc
# req_install.cpython-310.pyc
# req_set.cpython-310.pyc
# req_uninstall.cpython-310.pyc
# __init__.cpython-310.pyc
# base.py
# __init__.py
# resolver.py
# __init__.py
# resolver.cpython-310.pyc
# __init__.cpython-310.pyc
# base.py
# candidates.py
# factory.py
# found_candidates.py
# provider.py
# reporter.py
# requirements.py
# resolver.py
# __init__.py
# base.cpython-310.pyc
# candidates.cpython-310.pyc
# factory.cpython-310.pyc
# found_candidates.cpython-310.pyc
# provider.cpython-310.pyc
# reporter.cpython-310.pyc
# requirements.cpython-310.pyc
# resolver.cpython-310.pyc
# __init__.cpython-310.pyc
# base.cpython-310.pyc
# __init__.cpython-310.pyc
# appdirs.py
# compat.py
# compatibility_tags.py
# datetime.py
# deprecation.py
# direct_url_helpers.py
# distutils_args.py
# egg_link.py
# encoding.py
# entrypoints.py
# filesystem.py
# filetypes.py
# glibc.py
# hashes.py
# inject_securetransport.py
# logging.py
# misc.py
# models.py
# packaging.py
# setuptools_build.py
# subprocess.py
# temp_dir.py
# unpacking.py
# urls.py
# virtualenv.py
# wheel.py
# _log.py
# __init__.py
# appdirs.cpython-310.pyc
# compat.cpython-310.pyc
# compatibility_tags.cpython-310.pyc
# datetime.cpython-310.pyc
# deprecation.cpython-310.pyc
# direct_url_helpers.cpython-310.pyc
# distutils_args.cpython-310.pyc
# egg_link.cpython-310.pyc
# encoding.cpython-310.pyc
# entrypoints.cpython-310.pyc
# filesystem.cpython-310.pyc
# filetypes.cpython-310.pyc
# glibc.cpython-310.pyc
# hashes.cpython-310.pyc
# inject_securetransport.cpython-310.pyc
# logging.cpython-310.pyc
# misc.cpython-310.pyc
# models.cpython-310.pyc
# packaging.cpython-310.pyc
# setuptools_build.cpython-310.pyc
# subprocess.cpython-310.pyc
# temp_dir.cpython-310.pyc
# unpacking.cpython-310.pyc
# urls.cpython-310.pyc
# virtualenv.cpython-310.pyc
# wheel.cpython-310.pyc
# _log.cpython-310.pyc
# __init__.cpython-310.pyc
# bazaar.py
# git.py
# mercurial.py
# subversion.py
# versioncontrol.py
# __init__.py
# bazaar.cpython-310.pyc
# git.cpython-310.pyc
# mercurial.cpython-310.pyc
# subversion.cpython-310.pyc
# versioncontrol.cpython-310.pyc
# __init__.cpython-310.pyc
# build_env.cpython-310.pyc
# cache.cpython-310.pyc
# configuration.cpython-310.pyc
# exceptions.cpython-310.pyc
# main.cpython-310.pyc
# pyproject.cpython-310.pyc
# self_outdated_check.cpython-310.pyc
# wheel_builder.cpython-310.pyc
# __init__.cpython-310.pyc
# six.py
# typing_extensions.py
# vendor.txt
# __init__.py
# adapter.py
# cache.py
# compat.py
# controller.py
# filewrapper.py
# heuristics.py
# serialize.py
# wrapper.py
# _cmd.py
# __init__.py
# file_cache.py
# redis_cache.py
# __init__.py
# file_cache.cpython-310.pyc
# redis_cache.cpython-310.pyc
# __init__.cpython-310.pyc
# adapter.cpython-310.pyc
# cache.cpython-310.pyc
# compat.cpython-310.pyc
# controller.cpython-310.pyc
# filewrapper.cpython-310.pyc
# heuristics.cpython-310.pyc
# serialize.cpython-310.pyc
# wrapper.cpython-310.pyc
# _cmd.cpython-310.pyc
# __init__.cpython-310.pyc
# cacert.pem
# core.py
# __init__.py
# __main__.py
# core.cpython-310.pyc
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# big5freq.py
# big5prober.py
# chardistribution.py
# charsetgroupprober.py
# charsetprober.py
# codingstatemachine.py
# cp949prober.py
# enums.py
# escprober.py
# escsm.py
# eucjpprober.py
# euckrfreq.py
# euckrprober.py
# euctwfreq.py
# euctwprober.py
# gb2312freq.py
# gb2312prober.py
# hebrewprober.py
# jisfreq.py
# johabfreq.py
# johabprober.py
# jpcntx.py
# langbulgarianmodel.py
# langgreekmodel.py
# langhebrewmodel.py
# langhungarianmodel.py
# langrussianmodel.py
# langthaimodel.py
# langturkishmodel.py
# latin1prober.py
# mbcharsetprober.py
# mbcsgroupprober.py
# mbcssm.py
# sbcharsetprober.py
# sbcsgroupprober.py
# sjisprober.py
# universaldetector.py
# utf1632prober.py
# utf8prober.py
# version.py
# __init__.py
# chardetect.py
# __init__.py
# chardetect.cpython-310.pyc
# __init__.cpython-310.pyc
# languages.py
# __init__.py
# languages.cpython-310.pyc
# __init__.cpython-310.pyc
# big5freq.cpython-310.pyc
# big5prober.cpython-310.pyc
# chardistribution.cpython-310.pyc
# charsetgroupprober.cpython-310.pyc
# charsetprober.cpython-310.pyc
# codingstatemachine.cpython-310.pyc
# cp949prober.cpython-310.pyc
# enums.cpython-310.pyc
# escprober.cpython-310.pyc
# escsm.cpython-310.pyc
# eucjpprober.cpython-310.pyc
# euckrfreq.cpython-310.pyc
# euckrprober.cpython-310.pyc
# euctwfreq.cpython-310.pyc
# euctwprober.cpython-310.pyc
# gb2312freq.cpython-310.pyc
# gb2312prober.cpython-310.pyc
# hebrewprober.cpython-310.pyc
# jisfreq.cpython-310.pyc
# johabfreq.cpython-310.pyc
# johabprober.cpython-310.pyc
# jpcntx.cpython-310.pyc
# langbulgarianmodel.cpython-310.pyc
# langgreekmodel.cpython-310.pyc
# langhebrewmodel.cpython-310.pyc
# langhungarianmodel.cpython-310.pyc
# langrussianmodel.cpython-310.pyc
# langthaimodel.cpython-310.pyc
# langturkishmodel.cpython-310.pyc
# latin1prober.cpython-310.pyc
# mbcharsetprober.cpython-310.pyc
# mbcsgroupprober.cpython-310.pyc
# mbcssm.cpython-310.pyc
# sbcharsetprober.cpython-310.pyc
# sbcsgroupprober.cpython-310.pyc
# sjisprober.cpython-310.pyc
# universaldetector.cpython-310.pyc
# utf1632prober.cpython-310.pyc
# utf8prober.cpython-310.pyc
# version.cpython-310.pyc
# __init__.cpython-310.pyc
# ansi.py
# ansitowin32.py
# initialise.py
# win32.py
# winterm.py
# __init__.py
# ansi.cpython-310.pyc
# ansitowin32.cpython-310.pyc
# initialise.cpython-310.pyc
# win32.cpython-310.pyc
# winterm.cpython-310.pyc
# __init__.cpython-310.pyc
# compat.py
# database.py
# index.py
# locators.py
# manifest.py
# markers.py
# metadata.py
# resources.py
# scripts.py
# t32.exe
# t64-arm.exe
# t64.exe
# util.py
# version.py
# w32.exe
# w64-arm.exe
# w64.exe
# wheel.py
# __init__.py
# compat.cpython-310.pyc
# database.cpython-310.pyc
# index.cpython-310.pyc
# locators.cpython-310.pyc
# manifest.cpython-310.pyc
# markers.cpython-310.pyc
# metadata.cpython-310.pyc
# resources.cpython-310.pyc
# scripts.cpython-310.pyc
# util.cpython-310.pyc
# version.cpython-310.pyc
# wheel.cpython-310.pyc
# __init__.cpython-310.pyc
# distro.py
# __init__.py
# __main__.py
# distro.cpython-310.pyc
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# codec.py
# compat.py
# core.py
# idnadata.py
# intranges.py
# package_data.py
# uts46data.py
# __init__.py
# codec.cpython-310.pyc
# compat.cpython-310.pyc
# core.cpython-310.pyc
# idnadata.cpython-310.pyc
# intranges.cpython-310.pyc
# package_data.cpython-310.pyc
# uts46data.cpython-310.pyc
# __init__.cpython-310.pyc
# exceptions.py
# ext.py
# fallback.py
# __init__.py
# exceptions.cpython-310.pyc
# ext.cpython-310.pyc
# fallback.cpython-310.pyc
# __init__.cpython-310.pyc
# markers.py
# requirements.py
# specifiers.py
# tags.py
# utils.py
# version.py
# _manylinux.py
# _musllinux.py
# _structures.py
# __about__.py
# __init__.py
# markers.cpython-310.pyc
# requirements.cpython-310.pyc
# specifiers.cpython-310.pyc
# tags.cpython-310.pyc
# utils.cpython-310.pyc
# version.cpython-310.pyc
# _manylinux.cpython-310.pyc
# _musllinux.cpython-310.pyc
# _structures.cpython-310.pyc
# __about__.cpython-310.pyc
# __init__.cpython-310.pyc
# build.py
# check.py
# colorlog.py
# compat.py
# dirtools.py
# envbuild.py
# meta.py
# wrappers.py
# __init__.py
# _in_process.py
# __init__.py
# _in_process.cpython-310.pyc
# __init__.cpython-310.pyc
# build.cpython-310.pyc
# check.cpython-310.pyc
# colorlog.cpython-310.pyc
# compat.cpython-310.pyc
# dirtools.cpython-310.pyc
# envbuild.cpython-310.pyc
# meta.cpython-310.pyc
# wrappers.cpython-310.pyc
# __init__.cpython-310.pyc
# py31compat.py
# __init__.py
# py31compat.cpython-310.pyc
# __init__.cpython-310.pyc
# android.py
# api.py
# macos.py
# unix.py
# version.py
# windows.py
# __init__.py
# __main__.py
# android.cpython-310.pyc
# api.cpython-310.pyc
# macos.cpython-310.pyc
# unix.cpython-310.pyc
# version.cpython-310.pyc
# windows.cpython-310.pyc
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# cmdline.py
# console.py
# filter.py
# formatter.py
# lexer.py
# modeline.py
# plugin.py
# regexopt.py
# scanner.py
# sphinxext.py
# style.py
# token.py
# unistring.py
# util.py
# __init__.py
# __main__.py
# __init__.py
# __init__.cpython-310.pyc
# bbcode.py
# groff.py
# html.py
# img.py
# irc.py
# latex.py
# other.py
# pangomarkup.py
# rtf.py
# svg.py
# terminal.py
# terminal256.py
# _mapping.py
# __init__.py
# bbcode.cpython-310.pyc
# groff.cpython-310.pyc
# html.cpython-310.pyc
# img.cpython-310.pyc
# irc.cpython-310.pyc
# latex.cpython-310.pyc
# other.cpython-310.pyc
# pangomarkup.cpython-310.pyc
# rtf.cpython-310.pyc
# svg.cpython-310.pyc
# terminal.cpython-310.pyc
# terminal256.cpython-310.pyc
# _mapping.cpython-310.pyc
# __init__.cpython-310.pyc
# python.py
# _mapping.py
# __init__.py
# python.cpython-310.pyc
# _mapping.cpython-310.pyc
# __init__.cpython-310.pyc
# __init__.py
# __init__.cpython-310.pyc
# cmdline.cpython-310.pyc
# console.cpython-310.pyc
# filter.cpython-310.pyc
# formatter.cpython-310.pyc
# lexer.cpython-310.pyc
# modeline.cpython-310.pyc
# plugin.cpython-310.pyc
# regexopt.cpython-310.pyc
# scanner.cpython-310.pyc
# sphinxext.cpython-310.pyc
# style.cpython-310.pyc
# token.cpython-310.pyc
# unistring.cpython-310.pyc
# util.cpython-310.pyc
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# actions.py
# common.py
# core.py
# exceptions.py
# helpers.py
# results.py
# testing.py
# unicode.py
# util.py
# __init__.py
# __init__.py
# __init__.cpython-310.pyc
# actions.cpython-310.pyc
# common.cpython-310.pyc
# core.cpython-310.pyc
# exceptions.cpython-310.pyc
# helpers.cpython-310.pyc
# results.cpython-310.pyc
# testing.cpython-310.pyc
# unicode.cpython-310.pyc
# util.cpython-310.pyc
# __init__.cpython-310.pyc
# adapters.py
# api.py
# auth.py
# certs.py
# compat.py
# cookies.py
# exceptions.py
# help.py
# hooks.py
# models.py
# packages.py
# sessions.py
# status_codes.py
# structures.py
# utils.py
# _internal_utils.py
# __init__.py
# __version__.py
# adapters.cpython-310.pyc
# api.cpython-310.pyc
# auth.cpython-310.pyc
# certs.cpython-310.pyc
# compat.cpython-310.pyc
# cookies.cpython-310.pyc
# exceptions.cpython-310.pyc
# help.cpython-310.pyc
# hooks.cpython-310.pyc
# models.cpython-310.pyc
# packages.cpython-310.pyc
# sessions.cpython-310.pyc
# status_codes.cpython-310.pyc
# structures.cpython-310.pyc
# utils.cpython-310.pyc
# _internal_utils.cpython-310.pyc
# __init__.cpython-310.pyc
# __version__.cpython-310.pyc
# providers.py
# reporters.py
# resolvers.py
# structs.py
# __init__.py
# collections_abc.py
# __init__.py
# collections_abc.cpython-310.pyc
# __init__.cpython-310.pyc
# providers.cpython-310.pyc
# reporters.cpython-310.pyc
# resolvers.cpython-310.pyc
# structs.cpython-310.pyc
# __init__.cpython-310.pyc
# abc.py
# align.py
# ansi.py
# bar.py
# box.py
# cells.py
# color.py
# color_triplet.py
# columns.py
# console.py
# constrain.py
# containers.py
# control.py
# default_styles.py
# diagnose.py
# emoji.py
# errors.py
# filesize.py
# file_proxy.py
# highlighter.py
# json.py
# jupyter.py
# layout.py
# live.py
# live_render.py
# logging.py
# markup.py
# measure.py
# padding.py
# pager.py
# palette.py
# panel.py
# pretty.py
# progress.py
# progress_bar.py
# prompt.py
# protocol.py
# region.py
# repr.py
# rule.py
# scope.py
# screen.py
# segment.py
# spinner.py
# status.py
# style.py
# styled.py
# syntax.py
# table.py
# terminal_theme.py
# text.py
# theme.py
# themes.py
# traceback.py
# tree.py
# _cell_widths.py
# _emoji_codes.py
# _emoji_replace.py
# _export_format.py
# _extension.py
# _inspect.py
# _log_render.py
# _loop.py
# _palettes.py
# _pick.py
# _ratio.py
# _spinners.py
# _stack.py
# _timer.py
# _win32_console.py
# _windows.py
# _windows_renderer.py
# _wrap.py
# __init__.py
# __main__.py
# abc.cpython-310.pyc
# align.cpython-310.pyc
# ansi.cpython-310.pyc
# bar.cpython-310.pyc
# box.cpython-310.pyc
# cells.cpython-310.pyc
# color.cpython-310.pyc
# color_triplet.cpython-310.pyc
# columns.cpython-310.pyc
# console.cpython-310.pyc
# constrain.cpython-310.pyc
# containers.cpython-310.pyc
# control.cpython-310.pyc
# default_styles.cpython-310.pyc
# diagnose.cpython-310.pyc
# emoji.cpython-310.pyc
# errors.cpython-310.pyc
# filesize.cpython-310.pyc
# file_proxy.cpython-310.pyc
# highlighter.cpython-310.pyc
# json.cpython-310.pyc
# jupyter.cpython-310.pyc
# layout.cpython-310.pyc
# live.cpython-310.pyc
# live_render.cpython-310.pyc
# logging.cpython-310.pyc
# markup.cpython-310.pyc
# measure.cpython-310.pyc
# padding.cpython-310.pyc
# pager.cpython-310.pyc
# palette.cpython-310.pyc
# panel.cpython-310.pyc
# pretty.cpython-310.pyc
# progress.cpython-310.pyc
# progress_bar.cpython-310.pyc
# prompt.cpython-310.pyc
# protocol.cpython-310.pyc
# region.cpython-310.pyc
# repr.cpython-310.pyc
# rule.cpython-310.pyc
# scope.cpython-310.pyc
# screen.cpython-310.pyc
# segment.cpython-310.pyc
# spinner.cpython-310.pyc
# status.cpython-310.pyc
# style.cpython-310.pyc
# styled.cpython-310.pyc
# syntax.cpython-310.pyc
# table.cpython-310.pyc
# terminal_theme.cpython-310.pyc
# text.cpython-310.pyc
# theme.cpython-310.pyc
# themes.cpython-310.pyc
# traceback.cpython-310.pyc
# tree.cpython-310.pyc
# _cell_widths.cpython-310.pyc
# _emoji_codes.cpython-310.pyc
# _emoji_replace.cpython-310.pyc
# _export_format.cpython-310.pyc
# _extension.cpython-310.pyc
# _inspect.cpython-310.pyc
# _log_render.cpython-310.pyc
# _loop.cpython-310.pyc
# _palettes.cpython-310.pyc
# _pick.cpython-310.pyc
# _ratio.cpython-310.pyc
# _spinners.cpython-310.pyc
# _stack.cpython-310.pyc
# _timer.cpython-310.pyc
# _win32_console.cpython-310.pyc
# _windows.cpython-310.pyc
# _windows_renderer.cpython-310.pyc
# _wrap.cpython-310.pyc
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# after.py
# before.py
# before_sleep.py
# nap.py
# retry.py
# stop.py
# tornadoweb.py
# wait.py
# _asyncio.py
# _utils.py
# __init__.py
# after.cpython-310.pyc
# before.cpython-310.pyc
# before_sleep.cpython-310.pyc
# nap.cpython-310.pyc
# retry.cpython-310.pyc
# stop.cpython-310.pyc
# tornadoweb.cpython-310.pyc
# wait.cpython-310.pyc
# _asyncio.cpython-310.pyc
# _utils.cpython-310.pyc
# __init__.cpython-310.pyc
# _parser.py
# _re.py
# _types.py
# __init__.py
# _parser.cpython-310.pyc
# _re.cpython-310.pyc
# _types.cpython-310.pyc
# __init__.cpython-310.pyc
# connection.py
# connectionpool.py
# exceptions.py
# fields.py
# filepost.py
# poolmanager.py
# request.py
# response.py
# _collections.py
# _version.py
# __init__.py
# appengine.py
# ntlmpool.py
# pyopenssl.py
# securetransport.py
# socks.py
# _appengine_environ.py
# __init__.py
# bindings.py
# low_level.py
# __init__.py
# bindings.cpython-310.pyc
# low_level.cpython-310.pyc
# __init__.cpython-310.pyc
# appengine.cpython-310.pyc
# ntlmpool.cpython-310.pyc
# pyopenssl.cpython-310.pyc
# securetransport.cpython-310.pyc
# socks.cpython-310.pyc
# _appengine_environ.cpython-310.pyc
# __init__.cpython-310.pyc
# six.py
# __init__.py
# makefile.py
# __init__.py
# makefile.cpython-310.pyc
# __init__.cpython-310.pyc
# six.cpython-310.pyc
# __init__.cpython-310.pyc
# connection.py
# proxy.py
# queue.py
# request.py
# response.py
# retry.py
# ssltransport.py
# ssl_.py
# ssl_match_hostname.py
# timeout.py
# url.py
# wait.py
# __init__.py
# connection.cpython-310.pyc
# proxy.cpython-310.pyc
# queue.cpython-310.pyc
# request.cpython-310.pyc
# response.cpython-310.pyc
# retry.cpython-310.pyc
# ssltransport.cpython-310.pyc
# ssl_.cpython-310.pyc
# ssl_match_hostname.cpython-310.pyc
# timeout.cpython-310.pyc
# url.cpython-310.pyc
# wait.cpython-310.pyc
# __init__.cpython-310.pyc
# connection.cpython-310.pyc
# connectionpool.cpython-310.pyc
# exceptions.cpython-310.pyc
# fields.cpython-310.pyc
# filepost.cpython-310.pyc
# poolmanager.cpython-310.pyc
# request.cpython-310.pyc
# response.cpython-310.pyc
# _collections.cpython-310.pyc
# _version.cpython-310.pyc
# __init__.cpython-310.pyc
# labels.py
# mklabels.py
# tests.py
# x_user_defined.py
# __init__.py
# labels.cpython-310.pyc
# mklabels.cpython-310.pyc
# tests.cpython-310.pyc
# x_user_defined.cpython-310.pyc
# __init__.cpython-310.pyc
# six.cpython-310.pyc
# typing_extensions.cpython-310.pyc
# __init__.cpython-310.pyc
# __init__.cpython-310.pyc
# __main__.cpython-310.pyc
# __pip-runner__.cpython-310.pyc
# entry_points.txt
# INSTALLER
# LICENSE.txt
# METADATA
# RECORD
# REQUESTED
# top_level.txt
# WHEEL
# __init__.py
# __init__.py
# setup.py
# appdirs.py
# pyparsing.py
# __init__.py
# markers.py
# requirements.py
# specifiers.py
# tags.py
# utils.py
# version.py
# _manylinux.py
# _musllinux.py
# _structures.py
# __about__.py
# __init__.py
# INSTALLER
# METADATA
# namespace_packages.txt
# RECORD
# top_level.txt
# WHEEL
# archive_util.py
# build_meta.py
# cli-32.exe
# cli-64.exe
# cli-arm64.exe
# cli.exe
# config.py
# depends.py
# dep_util.py
# dist.py
# errors.py
# extension.py
# glob.py
# gui-32.exe
# gui-64.exe
# gui-arm64.exe
# gui.exe
# installer.py
# launch.py
# logging.py
# monkey.py
# msvc.py
# namespaces.py
# package_index.py
# py34compat.py
# sandbox.py
# script (dev).tmpl
# script.tmpl
# unicode_utils.py
# version.py
# wheel.py
# windows_support.py
# _deprecation_warning.py
# _imp.py
# __init__.py
# alias.py
# bdist_egg.py
# bdist_rpm.py
# build_clib.py
# build_ext.py
# build_py.py
# develop.py
# dist_info.py
# easy_install.py
# egg_info.py
# install.py
# install_egg_info.py
# install_lib.py
# install_scripts.py
# launcher manifest.xml
# py36compat.py
# register.py
# rotate.py
# saveopts.py
# sdist.py
# setopt.py
# test.py
# upload.py
# upload_docs.py
# __init__.py
# __init__.py
# archive_util.py
# bcppcompiler.py
# ccompiler.py
# cmd.py
# config.py
# core.py
# cygwinccompiler.py
# debug.py
# dep_util.py
# dir_util.py
# dist.py
# errors.py
# extension.py
# fancy_getopt.py
# filelist.py
# file_util.py
# log.py
# msvc9compiler.py
# msvccompiler.py
# py35compat.py
# py38compat.py
# spawn.py
# sysconfig.py
# text_file.py
# unixccompiler.py
# util.py
# version.py
# versionpredicate.py
# _msvccompiler.py
# __init__.py
# bdist.py
# bdist_dumb.py
# bdist_msi.py
# bdist_rpm.py
# bdist_wininst.py
# build.py
# build_clib.py
# build_ext.py
# build_py.py
# build_scripts.py
# check.py
# clean.py
# config.py
# install.py
# install_data.py
# install_egg_info.py
# install_headers.py
# install_lib.py
# install_scripts.py
# py37compat.py
# register.py
# sdist.py
# upload.py
# __init__.py
# ordered_set.py
# pyparsing.py
# __init__.py
# more.py
# recipes.py
# __init__.py
# markers.py
# requirements.py
# specifiers.py
# tags.py
# utils.py
# version.py
# _manylinux.py
# _musllinux.py
# _structures.py
# __about__.py
# __init__.py
# entry_points.txt
# INSTALLER
# LICENSE
# METADATA
# RECORD
# top_level.txt
# WHEEL
# bdist_wheel.py
# macosx_libfile.py
# metadata.py
# pkginfo.py
# util.py
# wheelfile.py
# __init__.py
# __main__.py
# convert.py
# pack.py
# unpack.py
# __init__.py
# __init__.py
# tags.py
# _typing.py
# __init__.py
# entry_points.txt
# INSTALLER
# LICENSE.txt
# METADATA
# RECORD
# top_level.txt
# WHEEL
# override.py
# __init__.py
# __init__.cpython-310.pyc
# _virtualenv.cpython-310.pyc
# activate
# activate.bat
# activate.fish
# activate.nu
# activate.ps1
# activate_this.py
# deactivate.bat
# deactivate.nu
# pip.exe
# pip3.10.exe
# pip3.exe
# pydoc.bat
# python.exe
# pythonw.exe
# wheel-3.10.exe
# wheel.exe
# wheel3.10.exe
# wheel3.exe
# 1.prime number.py
# 2.Print function.py
# main.py
# .gitignore
# 19th June Assignment.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# .gitignore
# CACHEDIR.TAG
# README.md
# lastfailed
# nodeids
# stepwise
# main.py
# TEST1.py
# .gitignore
# 23rdJuly.Exception Handling revision.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# test.py
# .gitignore
# 29th June.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# Assignment
# main.py
# test1.py
# test2.py
# .gitignore
# 2nd July class.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# test1.py
# test2.py
# util1.py
# .gitignore
# 3rd July Class.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# test1.cpython-310.pyc
# test2.cpython-310.pyc
# main.py
# taskget.py
# test1.py
# .gitignore
# API.iml
# misc.xml
# modules.xml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# mongotest.py
# test1.py
# COMMIT_EDITMSG
# config
# description
# HEAD
# index
# applypatch-msg.sample
# commit-msg.sample
# fsmonitor-watchman.sample
# post-update.sample
# pre-applypatch.sample
# pre-commit.sample
# pre-merge-commit.sample
# pre-push.sample
# pre-rebase.sample
# pre-receive.sample
# prepare-commit-msg.sample
# push-to-checkout.sample
# update.sample
# exclude
# HEAD
# master
# master
# 5ce2da2d6447d11dfe32bfb846c3d5b199fc99
# c5c59da6715cec590510bcd128a31a0bbcc658
# 9ec80ae5f765892b50a2f6e8246abc647a7f51
# d33521af10bcc7fd8cea344038eaaeb78d0ef5
# 76b867a05be0afda64f9d892451f1af9a8a3f2
# 5008645137f4089c78b4d7eee4a252b3ebd315
# 96b44786f04e4810aefe9f8d712f08ed310f71
# 4866cd0e4e38758e167fef157ee37fe68d0841
# 505d2e1e0395785b154a2f8e3eb40740106144
# a25f7f4cb416c083d265558da75d457237d671
# da6e58dd74556dd9550be721f0228779cbd268
# df22f06e38f320f13f02cd9b1d63affa8a64ae
# 876a78d06ac03b5d78c8dcdb95570281c6f1d6
# master
# master
# .gitignore
# misc.xml
# modules.xml
# MongoDB.iml
# vcs.xml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# test1.py
# test2.py
# test3.py
# .gitignore
# misc.xml
# modules.xml
# MongoDB1.iml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# test1.py
# test2.py
# test3.py
# .gitignore
# misc.xml
# modules.xml
# MySql.iml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# .gitignore
# misc.xml
# modules.xml
# new.iml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# data Abstraction.py
# Incapsulation.py
# main.py
# multi-level inheritance.py
# multiple inheritance.py
# overriding.py
# polymorphism.py
# test1.py
# .gitignore
# misc.xml
# modules.xml
# OOPS 3 26th july.iml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# main.py
# test1.py
# test2.py
# .gitignore
# misc.xml
# modules.xml
# OOPS2 24th july.iml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# util1.py
# util1.cpython-310.pyc
# test1.cpython-310.pyc
# test2.cpython-310.pyc
# main.py
# test.log
# test1.log
# test1.py
# test2.log
# test2.py
# test3.py
# test4.py
# test5.py
# test6.log
# test7.log
# test7.py
# .gitignore
# misc.xml
# modules.xml
# practice session15th july.iml
# workspace.xml
# profiles_settings.xml
# Project_Default.xml
# 2ndJuly OOPS.txt
# 3rdJuly OOPS.txt
# Python string basic  (2).ipynb
# python variable part 1 (1).ipynb
# googleplaystore.csv
# PYTHON_FEATURE_ENGINEERING_COOKBOOK.pdf
# student_performance.zip
# 1 . EDA STUDENT PERFORMANCE .ipynb
# 2 . FEATURE ENGINEERING .ipynb
# 3. OUTLIER DETECTION AND REMOVAL.ipynb
# 4. MODEL TRAINING.ipynb
# outlier_removed.csv
# README.md
# 1 . EDA STUDENT PERFORMANCE -checkpoint.ipynb
# 2 . FEATURE ENGINEERING -checkpoint.ipynb
# 3. OUTLIER DETECTION AND REMOVAL-checkpoint.ipynb
# 4. MODEL TRAINING-checkpoint.ipynb
# catboost_training.json
# learn_error.tsv
# time_left.tsv
# events.out.tfevents
# student.csv
# MongoDBlink.txt
# Power BI Material -Kundan.zip
# 1.Power BI Chart Practice.pbix
# 2.Power BI Map Practice.pbix
# 3. Power BI Table and Matrix.pbix
# 4. Power BI Other Charts.pbix
# 5. Power BI Cards and Filters.pbix
# 6. Power BI Slicers.pbix
# 7.Power BI Objects and Actions.pbix
# 8. Power BI Sample Superstore Report.pbix
# 9. Excel Merge Text (Power Query in Excel).xlsx
# 9. Power BI Power Query Text Merge.pbix
# Section 10.zip
# Section 11.zip
# Section 12.zip
# Section 13.zip
# Section 14.zip
# Section 15.zip
# Section 16.zip
# Section 17.zip
# Section 18.zip
# Section 2.zip
# Section 3.zip
# Section 4.zip
# Section 5.zip
# Section 6.zip
# Section 7.zip
# Section 8.zip
# Section 9.zip
# 10.1 Sample SuperStore.xlsx
# Sample Dashboard.pbix
# Section 10 - Publishing Reports to Power BI Service.pbix
# Section 10 - Reference.pbix
# 11. Power Query - Text Functions.xlsx
# Section 11 - PQ Text Functions.pbix
# 12. Power Query - Date Functions.xlsx
# Section 12 - PQ Date Functions.pbix
# 13. Power Query - Number Functions.xlsx
# Section 13 - PQ Number Functions.pbix
# 14.3 Append excel sheets with different columns.pbix
# 14.4 Append Multiple excel files from a folder.pbix
# 14.5 Append different data sources in Power bi.pbix
# Section 14 - Appending Files and Tables in Power BI.pbix
# APR_2020.csv
# Aug_2020.csv
# Feb_2020.csv
# Jan_2020.csv
# July_2020.csv
# June_2020.csv
# Mar_2020.csv
# May_2020.csv
# Annual Sales Details.xlsx
# Annual Sales Details (Diff Columns).xlsx
# APR_2020.xlsx
# Aug_2020.xlsx
# Feb_2020.xlsx
# Jan_2020.xlsx
# July_2020.xlsx
# June_2020.xlsx
# Mar_2020.xlsx
# May_2020.xlsx
# APR_2020.xlsx
# Mar_2020.csv
# Section 15 - Merging Tables in Power Query (Power BI).pbix
# 15.1 Merge Tables in Power Query (Power BI).xlsx
# (1) . Master Table.xlsx
# (2) Transactional Table.xlsx
# (1) . Master_EXCEL_File.xlsx
# (2) Transactional_CSV_File.csv
# (1) . Master Table.xlsx
# (2) Transactional Table.xlsx
# 16.1 Column from Example.xlsx
# 16.4 Conditional Column in Power BI.xlsx
# Section 16 - Column from Examples in Power Query (Power BI).pbix
# 17. Important Topics in Power Query.xlsx
# Section 17 -Miscellaneous Topics in Power BI.pbix
# 18. Sample Superstore for M Functions.xlsx
# Section 18 - Introduction to M Language.pbix
# Sample - Superstore.xlsx
# Section 2 - Basic Charts.pbix
# 3.4 State and UTs of India.xlsx
# Sample - Superstore.xlsx
# Section 3 - Maps.pbix
# Sample - Superstore.xlsx
# Section 4 - Table and Matrix.pbix
# Sample - Superstore.xlsx
# Section 5 - Other Charts.pbix
# Sample - Superstore.xlsx
# Section 6 - Cards and Filters.pbix
# Sample - Superstore.xlsx
# Section 7 - Slicers.pbix
# Sample - Superstore.xlsx
# Section 8 - Advanced Charts.pbix
# Section 9 - Objects and Actions (Hyperlinks).pbix
# CSV.png
# Excel.png
# Facebook.png
# Gartner.jpg
# Linkedin.png
# Oracle.png
# Pavan Lalwani.png
# SQL.png
# Udemy.png
# Website.jfif
# Website.png
# Youtube.png
# Youtube.webp
# Attribute DataSet.csv
# Dress Sales.csv
# Mysqlcsession.sql
# sql-course-materials.zip
# create-databases.sql
# create-db-hr.sql
# create-db-inventory.sql
# create-db-invoicing.sql
# create-db-store.sql
# 3.sql
# 4.sql
# 5.sql
# mosh.sql
# MySQL with Mosh.sql
# ._create-databases.sql
# ._create-db-hr.sql
# ._create-db-inventory.sql
# ._create-db-invoicing.sql
# ._create-db-store.sql
# Numpy and basic of graph.ipynb
# data fsds -20220829T132733Z-001.zip
# pandas basic intro, Datasets.txt
# test.csv
# test123.csv
# test1234.csv
# Attribute DataSet.xlsx
# Dress Sales.xlsx
# haberman.csv
# haberman.names
# haberman1.csv
# Online Retail (1).xlsx
# Online Retail.xlsx
# online_retail_II (1).xlsx
# pollution.csv
# pollution.names
# URL Table.txt
# AgentLogingReport.csv
# AgentPerformance.csv
# Dress Sales CSV.csv
# pandas class 2.ipynb
# sales_data_final (1).csv
# task -20220924T033240Z-001.zip
# FitBit data.csv
# pandas class 3 - with task .ipynb
# sales_data_final (1).csv
# Superstore_USA.xlsx
# acknowledgement Certificate.pdf
# Application for LL LMV.pdf
# fitness form.pdf
# Payment Receipt LL.pdf
# sawan.pdf
# Algerian_forest_fires_dataset_UPDATE.csv
# archive.zip
# EDA-Used-CAr-PRediction-main.zip
# statistics-interview-questions.pdf
# T-test-an-Correlation-using-python-master.zip
# Types-Of-Trnasformation-main.zip
# Data_Train.xlsx
# Sample_submission.xlsx
# Test_set.xlsx
# 1. EDA Used Car Prediction.ipynb
# LICENSE
# README.md
# cardekho_dataset.csv
# Hypothesis_Testing.ipynb
# README.md
# 6931938-ef43d46682f2792eeeb30901cc830f37.pdf
# @Jesseverse_Avatar_2009_BluRay_EXTENDED_720p_Hindi_English_AAC_5.mkv
# aattam kalasamithi_ violin fusion ft chemmeen band _3 _bgm music.mp3
# Avatar The Way of Water 2022 1080p WEB-DL DD5.1 x265-TFP.mkv
# Backbenchers season 2 episode-6 sad bgm __ DST.mp3
# Backbenchers season 2 _ Sad bgm _ emotional scene _  Tej india.mp3
# Ballarpur to Pune 4th June sawan.PDF
# Black Adam.mkv
# Bullet_Train_2022_1080p_10bit_WEBRip_6CH_x265_HEVC_PSA_STARCINEMA.mkv
# Combined23AdmissionCertificate (1).pdf
# desktop.ini
# Dhamaka_2022_720p_WEB_DL_Telugu_DD+_5_1_192Kbps_&_AAC_2_0_H264_ESubs.mkv
# DJ Tillu 2022 Telugu 1080p AAC x265 ESUB @MWKOTT.mkv
# Dont knock twice.mkv
# Doraemon Nobita and the steel troops THE NEW AGE.mp4
# Gadar-Ek Prem Katha 2001.mkv
# Goodbye 2022 WebRip Hindi 720p.mkv
# Introduction to SQL.pdf
# Monica_O_My_Darling_2022_WebRip_720p.mkv
# MPSC.SS.preAdmissionCertificate.pdf
# Nanu Vadhilelina Thanatho Lyrical Song __ Backbenchers Web Series __ Dorasai Teja __ Infinitum Media.mp3
# Ori_Devuda_2022_Telugu_TRUE_WEB_DL_720p_HQ_AVC_DD+_5_1_192Kbps_&.mkv
# Pictures - Shortcut.lnk
# shazam.fury.of.the.gods.2023.1080p.web.hevc.x265.mkv
# Talathi Bharati .pdf
# Tg @MoviessFire Thackeray ( 2019 ) Hindi HDTV 720p x264.mkv
# Tg_@MoviessFireSarsenapati_Hambirrao_2022_Marathi_HDTV_Rip_720p.mkv
# Tg_@MoviessFire_Aapdi_Thaapdi_720p_AMZN_WEB_DL_Marathi_DDP5_1_H.mkv
# Tg_@MoviessFire_Army_of_the_Dead_2021_WebRip_720p_Hindi_English.mkv
# Tg_@MoviessFire_Killa_Aka_The_Fort_किल्ला_2014_Marathi_Web_Rip_720p.mkv
# Tg_@MoviessFire_Rorschach_2022_WebRip_720p_Hindi_Malayalam_AAC_5.mkv
# The.Invitation.2022.UNRATED.1080p.10bit.WEBRip STARCINEMA.mkv
# Theerppu.MAL.2022.720p.10bit.DSNP.2CH.HEVC.Esub~ALB STARCIN.mkv
# Transformers-(2007)-Telugu-Dubbed-BRRip-Single-Part-HQ-E-Sub.mp4
# Ved.2022.720p.HS.WEB-DL.Hindi+Marathi.DDP5.1.H.265-Archi.mkv
# [FC] Enemy (2022) Telugu HDRip .mkv
# [FC] Laal Singh Chaddha (2022) [Hindi - 720p HDRip - DD.mkv
# [FC] Tu Jhoothi Main Makkaar (2023) Hindi HDRip ESub.mkv
# Friends S04.mkv
# Friends S06.mkv
# Friends S07.mkv
# Friends_S05_COMBINED_720p_BluRay_2CH_x265_HEVC_ESub_Anmol_PSA.mkv
# Friends_S08_COMBINED_720p_BluRay_2CH_x265_HEVC_ESub_Anmol_PSA.mkv
# Friends_S09_COMBINED_720p_BluRay_2CH_x265_HEVC_ESub_Anmol_PSA.mkv
# Friends_S10_COMBINED_720p_BluRay_2CH_x265_HEVC_ESub_Anmol_PSA.mkv
# zoo.cpython-39.pyc

# %% [markdown]
# ### 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()
    
print(procOne(),
     procTwo(),
     procThree())
# Out:
# Proc_one_Starttime -> 2023-05-17 11:24:30.923931
# Proc_one_Endtime -> 2023-05-17 11:24:31.926174
# Proc_two_Starttime -> 2023-05-17 11:24:31.926174
# Proc_two_Endtime -> 2023-05-17 11:24:33.935904
# Proc_two_Starttime -> 2023-05-17 11:24:33.935904
# Proc_two_Endtime -> 2023-05-17 11:24:37.941791
# None None None

# %% [markdown]
# ### 7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('26/04/1994','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1994-04-26 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# ### 8. What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(1994,4,26)
my_dob.strftime("%A")
# Out:
# 'Tuesday'

# %% [markdown]
# ### 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("26/04/1994",'%d/%m/%Y')
future_date = my_dob-timedelta(-10000)
future_date
# Out:
# datetime.datetime(2021, 9, 11, 0, 0)
